# %%
import pandas as pd

# %%
df = pd.read_csv('a.csv')
df.head()
# Out:
#    Temperature  Light  Wind  Pressure  Voltage  Team                    Date
# 0          8.0     47   1.3      1021      6.8     0   Thu 24.03.2016 14:29
# 1          8.5     49   0.5      1022      6.9     0   Thu 24.03.2016 14:27
# 2          9.0     56   0.7      1022      6.9     0   Thu 24.03.2016 14:25
# 3          9.5     50   0.2      1021      7.0     0   Thu 24.03.2016 14:23
# 4         10.0     43   0.6      1021      7.0     0   Thu 24.03.2016 14:21

# %%
df.columns
# Out:
# Index(['Temperature', 'Light', 'Wind', 'Pressure', 'Voltage', 'Team', 'Date'], dtype='object')

# %%
df['Date'] =pd.to_datetime(df.Date)
df.sort_values(by='Date', ascending=False) # This now sorts in date order
# Out:
#     Temperature  Light  Wind  Pressure  Voltage  Team                Date
# 0           8.0     47   1.3      1021      6.8     0 2016-03-24 14:29:00
# 1           8.5     49   0.5      1022      6.9     0 2016-03-24 14:27:00
# 2           9.0     56   0.7      1022      6.9     0 2016-03-24 14:25:00
# 3           9.5     50   0.2      1021      7.0     0 2016-03-24 14:23:00
# 4          10.0     43   0.6      1021      7.0     0 2016-03-24 14:21:00
# 5          10.0     25   1.1      1020      7.1     0 2016-03-24 14:19:00
# 6           9.5     46   0.4      1022      7.1     0 2016-03-24 14:16:00
# 7          10.0     48   0.2      1021      7.1     0 2016-03-24 14:14:00
# 8          10.0     48   1.0      1021      7.2     0 2016-03-24 14:12:00
# 9          12.0     45   0.3      1021      7.2     0 2016-03-24 14:10:00
# 10         11.0     22   0.4      1020      7.2     0 2016-03-24 14:08:00
# 11         11.0     22   0.5      1020      7.2     0 2016-03-24 14:06:00
# ...

# %%
import random
l = []
for i in range(100):
    l.append({
        "temp": random.random(),
         "voltage"
    })
l[0]['temp']
# Out:
# 0.23997858573950648
